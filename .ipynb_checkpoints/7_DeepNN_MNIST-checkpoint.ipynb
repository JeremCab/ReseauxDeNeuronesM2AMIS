# %% [markdown]
# # Neural Networks in ``PyTorch``

# %% [markdown]
# The **MNIST dataset** consists of 60,000 images of hand written digit, where each image has size 28X28.
#
# <img src="files/figures/mnist.png" width="600px"/>
#
# We will define and train a deep neural network on the MNIST dataset. This is a **classification problem**.<br>
#
# The definition and training of a neural network invoves the following steps:
#
# 0. Import **librairies**;
# 1. Get the **datasets** (train and test);
# 2. Define the **dataloaders** from the datasets (train and test);
# 3. Define the **model**;
# 4. Define the **loss function**;
# 5. Define the **optimizer**;
# 7. **Train** the model (training loop);
# 8. Get the **results** (predict).

# %% [markdown]
# ## 0. Librairies

# %%
import os

import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision.datasets as datasets
from torchvision.transforms import ToTensor

from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

from tqdm.notebook import tqdm

# %% [markdown]
# ## 1. Datasets

# %% [markdown]
# - Load the train and test MNIST datasets using the following commands:<br>
# ```
# train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=ToTensor())
# test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=ToTensor())
# ```
# Each sample consists of a tensor (the image encoded in black and white), and a label (the digit that it represents).
#
# - Examine the data (structure, dimension, etc).
# - Create a function to visualize some data as an image.

# %%
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=ToTensor())
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=ToTensor())

# %%
len(train_dataset), len(test_dataset)
# Out:
# (60000, 10000)

# %%
# Each sample data is a tuple: tensor [1, 28, 28], label
train_dataset[0][0].shape, train_dataset[0][1]
# Out:
# (torch.Size([1, 28, 28]), 5)

# %%
def display_data(sample):
    
    # get tensor and label
    tensor, label = sample[0], sample[1]
    tensor = tensor.view(28, 28) # reshape into 28 x 28
    
    # plot
    plt.figure(figsize=(2, 2))
    plt.title(f'label: {label}')
    plt.imshow(tensor)
    plt.show()

# %%
def display_some_data(dataset):
    
    fig, axs = plt.subplots(5, 5, figsize=(10,10))
    
    for i in range(25):
        
        tensor, label = dataset[i][0], dataset[i][1]
        
        axs[i//5, i%5].set_title(f"Label: {label}")
        axs[i//5, i%5].imshow(tensor.view(28, 28))
    
    plt.show()

# %%
display_some_data(train_dataset)

# %% [markdown]
# ## 2. Dataloaders

# %% [markdown]
# A **dataloader** creates batches of samples from a dataset so that they can be passed into a model.
# - Create a train and test dataloaders using the following commands:
# ```
# train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
# test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True)
# ```
# - Note that dataloaders are not subscriptable.
# - Try to catch one batch of the dataloader and examine it.
# - Write a function that reshapes a batch of size $64 \times 1 \times 28 \times 28$ into a tensor of size $64 \times 784$.<br>
# (use `torch.squeeze()`, `torch.reshape()`, `torch.flatten()`, `torch.transpose()`, etc.)

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=64, shuffle=True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=64, shuffle=True)

# %%
def reshape_batch(batch):
    
    # note that this function moodifies the batch in-place (no return)
    batch_size = batch[0].shape[0]
    batch[0] = batch[0].view(batch_size, -1)

# %%
for b in train_dataloader:
    break

# %%
b[0].shape
# Out:
# torch.Size([64, 1, 28, 28])

# %%
reshape_batch(b)

# %%
b[0].shape
# Out:
# torch.Size([64, 784])

# %% [markdown]
# ## 3. Model

# %% [markdown]
# - Define and instanciate a **neural network** with the following feaures:
#     - hidden layer 1: 256 neurons, relu activation function
#     - hidden layer 2: 256 neurons, relu activation function
#     - hidden layer 3: 128 neurons, relu activation function
#     - hidden layer 4: 64 neurons, relu activation function
#     - output layer: 10 neurons

# %%
class Network(nn.Module):

    def __init__(self):
        
        super(Network, self).__init__()
        
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 256)
        self.fc3 = nn.Linear(256, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 10)

    def forward(self, x):
        
        x = self.fc1(x)
        x = nn.ReLU()(x)
        
        x = self.fc2(x)
        x = nn.ReLU()(x)
        
        x = self.fc3(x)
        x = nn.ReLU()(x)
        
        x = self.fc4(x)
        x = nn.ReLU()(x)
        
        x = self.fc5(x)
        
        return x

# %%
network = Network()

# %%
# Put network to GPU if exists
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
network.to(device)
# Out:
# Network(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
network
# Out:
# Network(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ## 4. Loss

# %% [markdown]
# - Define a **cross entropy loss** with the following command:<br>
# ```
# loss = nn.CrossEntropyLoss()
# ```
# - Try to understand this loss object:<br>
# https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html

# %%
loss = nn.CrossEntropyLoss()

# %% [markdown]
# ## 5. Optimizer

# %% [markdown]
# - Define an **SGD optimizer** with the following command:<br>
# ```
# optimizer = torch.optim.SGD(network.parameters(), lr=0.005)
# ```
# - Try to understand this object:<br>
# https://pytorch.org/docs/stable/generated/torch.optim.SGD.html#torch.optim.SGD

# %%
optimizer = torch.optim.SGD(network.parameters(), lr=0.005)

# %% [markdown]
# ## 6. Training

# %% [markdown]
# - Define a **training loop** for you model.
# - The key instructions are:
#     - ``optimizer.zero_grad()``: reset gradients to 0
#     - ``loss.backward()``      : compute new gradients
#     - ``optimizer.step()``     : uptdate weights
# - Train the model for 20 epochs.
# - Plot the training loss.

# %%
def train(model, loss=None, optimizer=None, dataloader=None, nb_epochs=20):
    """Training loop"""
    
    loss_l = []
        
    for e in tqdm(range(nb_epochs)):
    
        for i, batch in enumerate(dataloader):   # iterate over dataloader

            reshape_batch(batch)
            samples, labels = batch[0], batch[1]

            outputs = model(samples)

            current_loss = loss(outputs, labels) # compute loss
            optimizer.zero_grad()                # reset gradients to 0
            current_loss.backward()              # computer gradients
            optimizer.step()                     # update weights

            if i % 100 == 0: # every 100 batches

                loss_l.append(current_loss.item())

                print(f"Epoch: {e}/{nb_epochs}. \t step: {i} \t loss: {current_loss.item()}")
            
    return loss_l

# %%
loss_l = train(network, 
               loss=loss, 
               optimizer=optimizer, 
               dataloader=train_dataloader, 
               nb_epochs=20)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20.0), HTML(value='')))
# Epoch: 0/20. 	 step: 0 	 loss: 2.306914806365967
# Epoch: 0/20. 	 step: 100 	 loss: 2.303662061691284
# Epoch: 0/20. 	 step: 200 	 loss: 2.301288366317749
# Epoch: 0/20. 	 step: 300 	 loss: 2.300276041030884
# Epoch: 0/20. 	 step: 400 	 loss: 2.28977108001709
# Epoch: 0/20. 	 step: 500 	 loss: 2.3070967197418213
# Epoch: 0/20. 	 step: 600 	 loss: 2.2956087589263916
# Epoch: 0/20. 	 step: 700 	 loss: 2.2960879802703857
# Epoch: 0/20. 	 step: 800 	 loss: 2.29141902923584
# Epoch: 0/20. 	 step: 900 	 loss: 2.2903873920440674
# Epoch: 1/20. 	 step: 0 	 loss: 2.2855446338653564
# Epoch: 1/20. 	 step: 100 	 loss: 2.2892394065856934
# Epoch: 1/20. 	 step: 200 	 loss: 2.292618989944458
# Epoch: 1/20. 	 step: 300 	 loss: 2.286062717437744
# Epoch: 1/20. 	 step: 400 	 loss: 2.2906501293182373
# Epoch: 1/20. 	 step: 500 	 loss: 2.2839930057525635
# Epoch: 1/20. 	 step: 600 	 loss: 2.293217420578003
# Epoch: 19/20. 	 step: 400 	 loss: 0.15170592069625854
# Epoch: 19/20. 	 step: 500 	 loss: 0.16024194657802582
# Epoch: 19/20. 	 step: 600 	 loss: 0.13440726697444916
# Epoch: 19/20. 	 step: 700 	 loss: 0.31182944774627686
# Epoch: 19/20. 	 step: 800 	 loss: 0.24358722567558289
# Epoch: 19/20. 	 step: 900 	 loss: 0.2172861397266388

# %%
# plot loss
plt.plot(range(len(loss_l)), loss_l, 
         linewidth=2.0, 
         label='training loss')

plt.xlabel("Epochs)", size=12)
plt.ylabel("Loss", size=12)
plt.legend()

plt.show()

# %% [markdown]
# ## 6. Predictions

# %% [markdown]
# - Write a ``predict`` function
#     - use ``with torch.no_grad():``
# - Compute the accuracy and classification report of the train and test sets.

# %%
def predict(model, dataloader):

    labels_l = []
    preds_l = []

    with torch.no_grad():
        
        for i, batch in enumerate(dataloader):   # iterate over dataloader

            reshape_batch(batch)
            samples, labels = batch[0], batch[1]
            
            labels_l.extend(labels.tolist())
            
            preds = model(samples)
            preds = torch.argmax(preds, dim=1)
            preds_l.extend(preds.tolist())
    
    return labels_l, preds_l

# %%
train_labels_l, train_preds_l = predict(network, train_dataloader)
test_labels_l, test_preds_l = predict(network, test_dataloader)

# %%
print(classification_report(train_labels_l, train_preds_l))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      5923
#            1       0.97      0.98      0.97      6742
#            2       0.96      0.95      0.95      5958
#            3       0.96      0.94      0.95      6131
#            4       0.95      0.96      0.96      5842
#            5       0.96      0.94      0.95      5421
#            6       0.95      0.98      0.96      5918
#            7       0.96      0.96      0.96      6265
#            8       0.93      0.94      0.93      5851
#            9       0.92      0.93      0.93      5949
#
#     accuracy                           0.95     60000
#    macro avg       0.95      0.95      0.95     60000
# weighted avg       0.95      0.95      0.95     60000

# %%
print(classification_report(test_labels_l, test_preds_l))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       980
#            1       0.97      0.99      0.98      1135
#            2       0.95      0.94      0.95      1032
#            3       0.96      0.94      0.95      1010
#            4       0.94      0.97      0.95       982
#            5       0.96      0.93      0.94       892
#            6       0.94      0.96      0.95       958
#            7       0.96      0.94      0.95      1028
#            8       0.92      0.93      0.93       974
#            9       0.93      0.93      0.93      1009
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000

# %% [markdown]
# ## 7. Save

# %% [markdown]
# - Save your trained model.
# - Try to reload it and see if it works.
# - Use the following instructions
# ```
# torch.save(model.state_dict(), <path>)
# ...
# network_2.load_state_dict(torch.load(<path>))
# network_2.eval()
# ```

# %%
cwd = os.getcwd()
path = os.path.join(cwd, "model.pt")

# %%
torch.save(network.state_dict(), path)

# %%
network_2 = Network()

# %%
network_2.load_state_dict(torch.load(path))
network_2.eval()
# Out:
# Network(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
test_labels_l, test_preds_l = predict(network_2, test_dataloader)

# %%
print(classification_report(test_labels_l, test_preds_l))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       980
#            1       0.97      0.99      0.98      1135
#            2       0.95      0.94      0.95      1032
#            3       0.96      0.94      0.95      1010
#            4       0.94      0.97      0.95       982
#            5       0.96      0.93      0.94       892
#            6       0.94      0.96      0.95       958
#            7       0.96      0.94      0.95      1028
#            8       0.92      0.93      0.93       974
#            9       0.93      0.93      0.93      1009
#
#     accuracy                           0.95     10000
#    macro avg       0.95      0.95      0.95     10000
# weighted avg       0.95      0.95      0.95     10000
