# %% [markdown]
# # Autoencoders (AE)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

import matplotlib.pyplot as plt

# %% [markdown]
# ## Load MNIST data

# %%
transform = transforms.ToTensor()

#transform = transforms.Compose( [transforms.ToTensor(),
#                                 transforms.Normalize((0.5),(0.5))] )

mnist_data = datasets.MNIST(root='./data', train=True,
                            download=True,
                            transform=transform)

# %%
len(mnist_data)
# Out:
# 60000

# %%
train_set, val_set = torch.utils.data.random_split(mnist_data, [50000, 10000])

train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=64, shuffle=True)
val_loader = torch.utils.data.DataLoader(dataset=val_set, batch_size=64, shuffle=True)

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)

# %%
images.shape, labels.shape
# Out:
# (torch.Size([64, 1, 28, 28]), torch.Size([64]))

# %%
torch.min(images), torch.max(images)
# Out:
# (tensor(0.), tensor(1.))

# %% [markdown]
# ## Model 1: AE with linear layers

# %% [markdown]
# ### Model

# %%
torch.cuda.is_available()
# Out:
# False

# %%
class Autoencoder_Linear(nn.Module):
    """Implements an linear automencoder"""

    def __init__(self):
        """constructor"""

        super().__init__()

        self.encoder = nn.Sequential(
            nn.Linear(28 * 28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 12),
            nn.ReLU(),
            nn.Linear(12, 2) # -> N, 2 only!
        )

        self.decoder = nn.Sequential(
            nn.Linear(2, 12),
            nn.ReLU(),
            nn.Linear(12, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 28 * 28),
            nn.Sigmoid()             # output neurons between 0 and 1
        )

    def forward(self, x):
        """forward pass"""
        
        encoded_data = self.encoder(x)
        decoded_data = self.decoder(encoded_data)

        return decoded_data

# %%
model_1 = Autoencoder_Linear()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model_1.parameters(), 
                             lr=1e-3, 
                             weight_decay=1e-5)

# %% [markdown]
# ### Training

# %%
num_epochs = 24
outputs_l = []

for epoch in range(num_epochs):

    train_loss = []
    val_loss = []

    for (inputs, _) in train_loader:

        inputs = inputs.reshape(-1, 28*28) # reshape data 28 x 28 -> 784
        outputs = model_1(inputs)

        loss = criterion(outputs, inputs)
        train_loss.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    train_loss = torch.mean(torch.tensor(train_loss)).item()

    for (inputs, _) in val_loader:

        inputs = inputs.reshape(-1, 28*28) # reshape data 28 x 28 -> 784
        outputs = model_1(inputs)

        loss = criterion(outputs, inputs)
        val_loss.append(loss.item())

    val_loss = torch.mean(torch.tensor(val_loss)).item()

    print(f'Epoch:{epoch+1} \t Train loss: {train_loss:.4f} \t \
                             Validation loss: {val_loss:.4f}')

    outputs_l.append((epoch, inputs, outputs, train_loss, val_loss))
# Out:
# Epoch:1 	 Train loss: 0.0620 	                              Validation loss: 0.0537
# Epoch:2 	 Train loss: 0.0520 	                              Validation loss: 0.0510
# Epoch:3 	 Train loss: 0.0493 	                              Validation loss: 0.0482
# Epoch:4 	 Train loss: 0.0471 	                              Validation loss: 0.0468
# Epoch:5 	 Train loss: 0.0459 	                              Validation loss: 0.0454
# Epoch:6 	 Train loss: 0.0450 	                              Validation loss: 0.0448
# Epoch:7 	 Train loss: 0.0443 	                              Validation loss: 0.0441
# Epoch:8 	 Train loss: 0.0437 	                              Validation loss: 0.0437
# Epoch:9 	 Train loss: 0.0432 	                              Validation loss: 0.0432
# Epoch:10 	 Train loss: 0.0427 	                              Validation loss: 0.0429
# Epoch:11 	 Train loss: 0.0424 	                              Validation loss: 0.0423
# Epoch:12 	 Train loss: 0.0421 	                              Validation loss: 0.0422
# Epoch:13 	 Train loss: 0.0417 	                              Validation loss: 0.0417
# Epoch:14 	 Train loss: 0.0414 	                              Validation loss: 0.0418
# Epoch:15 	 Train loss: 0.0412 	                              Validation loss: 0.0415
# Epoch:16 	 Train loss: 0.0409 	                              Validation loss: 0.0410
# Epoch:17 	 Train loss: 0.0407 	                              Validation loss: 0.0408
# Epoch:18 	 Train loss: 0.0405 	                              Validation loss: 0.0407
# Epoch:19 	 Train loss: 0.0403 	                              Validation loss: 0.0405
# Epoch:20 	 Train loss: 0.0401 	                              Validation loss: 0.0404
# Epoch:21 	 Train loss: 0.0399 	                              Validation loss: 0.0401
# Epoch:22 	 Train loss: 0.0396 	                              Validation loss: 0.0398
# Epoch:23 	 Train loss: 0.0395 	                              Validation loss: 0.0397
# Epoch:24 	 Train loss: 0.0394 	                              Validation loss: 0.0397

# %% [markdown]
# ### Results

# %%
plt.figure(figsize=(5, 3))

epochs = [x[0] for x in outputs_l]
train_loss = [x[3] for x in outputs_l]
val_loss = [x[4] for x in outputs_l]

plt.plot(epochs, train_loss, label="training loss")
plt.plot(epochs, val_loss, label="validation loss")
plt.xlabel("epochs")
plt.ylabel("MSE loss")
plt.legend()
plt.savefig('figures/AE_linear_loss.pdf', format='pdf', bbox_inches='tight')
#plt.show()

# %%
fig, axs = plt.subplots(6, 10, 
                        figsize=(10, 7), 
                        layout="constrained",
                        gridspec_kw={'wspace': 0.1, 'hspace': 0.1})

for i, k in enumerate([0, num_epochs//2, num_epochs-1]):

    inputs = outputs_l[k][1].detach().numpy()
    outputs = outputs_l[k][2].detach().numpy()

    axs[2*i, 0].set_title(f"Epoch {k+1}")
    axs[2*i, 0].set_ylabel("Inputs")

    for j, item in enumerate(inputs):

        if j >= 10: break
        item = item.reshape(-1, 28,28) # for Autoencoder_Linear
        axs[2*i, j].imshow(item[0])
        axs[2*i, j].set_xticks([])
        axs[2*i, j].set_yticks([])

    axs[2*i + 1, 0].set_ylabel("Outputs")
    for j, item in enumerate(outputs):

        if j >= 10: break
        item = item.reshape(-1, 28,28) # for Autoencoder_Linear
        axs[2*i + 1, j].imshow(item[0])
        axs[2*i + 1, j].set_xticks([])
        axs[2*i + 1, j].set_yticks([])

fig.savefig('figures/AE_linear.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Model 2: AE with convolutional layers

# %% [markdown]
# ### Model

# %%
class Autoencoder_CNN(nn.Module):
    """Implements a CNN autoencoder"""

    def __init__(self):
        """constructor"""

        super().__init__()

        # N, 1, 28, 28
        self.encoder = nn.Sequential(
            # -> N, 16, 14, 14
            nn.Conv2d(1, 16, 3, stride=2, padding=1),
            nn.ReLU(),
            # -> N, 32, 7, 7
            nn.Conv2d(16, 32, 3, stride=2, padding=1),
            nn.ReLU(),
            # -> N, 64, 1, 1
            nn.Conv2d(32, 64, 7)
            )

        # N , 64, 1, 1
        self.decoder = nn.Sequential(
            # -> N, 32, 7, 7
            nn.ConvTranspose2d(64, 32, 7),
            nn.ReLU(),
            # N, 16, 14, 14 (N, 16, 13, 13 without output_padding)
            nn.ConvTranspose2d(32, 16, 3, 
                               stride=2, padding=1, output_padding=1),
            nn.ReLU(),
            # N, 1, 28, 28 (N,1, 27, 27)
            nn.ConvTranspose2d(16, 1, 3, 
                               stride=2, padding=1, output_padding=1),
            nn.Sigmoid()
            )

    def forward(self, x):
        """forward function"""

        encoded_data = self.encoder(x)
        decoded_data = self.decoder(encoded_data)

        return decoded_data


# Note: nn.MaxPool2d -> use nn.MaxUnpool2d, or use different kernelsize, stride etc to compensate...
# Input [-1, +1] -> use nn.Tanh

# %%
model_2 = Autoencoder_CNN()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model_2.parameters(), 
                             lr=1e-3, 
                             weight_decay=1e-5)

# %% [markdown]
# ### Traning

# %%
num_epochs = 12
outputs_l = []

for epoch in range(num_epochs):

    train_loss = []
    val_loss = []

    for (inputs, _) in train_loader:

        # inputs = inputs.reshape(-1, 28*28) # reshape data 28 x 28 -> 784
        outputs = model_2(inputs)

        loss = criterion(outputs, inputs)
        train_loss.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    train_loss = torch.mean(torch.tensor(train_loss)).item()

    for (inputs, _) in val_loader:

        # inputs = inputs.reshape(-1, 28*28) # reshape data 28 x 28 -> 784
        outputs = model_2(inputs)

        loss = criterion(outputs, inputs)
        val_loss.append(loss.item())

    val_loss = torch.mean(torch.tensor(val_loss)).item()

    print(f'Epoch:{epoch+1} \t Train loss: {train_loss:.4f} \t \
                             Validation loss: {val_loss:.4f}')

    outputs_l.append((epoch, inputs, outputs, train_loss, val_loss))
# Out:
# Epoch:1 	 Train loss: 0.0386 	                              Validation loss: 0.0108
# Epoch:2 	 Train loss: 0.0080 	                              Validation loss: 0.0064
# Epoch:3 	 Train loss: 0.0054 	                              Validation loss: 0.0047
# Epoch:4 	 Train loss: 0.0043 	                              Validation loss: 0.0040
# Epoch:5 	 Train loss: 0.0037 	                              Validation loss: 0.0035
# Epoch:6 	 Train loss: 0.0033 	                              Validation loss: 0.0034
# Epoch:7 	 Train loss: 0.0031 	                              Validation loss: 0.0031
# Epoch:8 	 Train loss: 0.0030 	                              Validation loss: 0.0030
# Epoch:9 	 Train loss: 0.0029 	                              Validation loss: 0.0030
# Epoch:10 	 Train loss: 0.0029 	                              Validation loss: 0.0030
# Epoch:11 	 Train loss: 0.0028 	                              Validation loss: 0.0029
# Epoch:12 	 Train loss: 0.0028 	                              Validation loss: 0.0028

# %% [markdown]
# ### Results

# %%
plt.figure(figsize=(5, 3))

epochs = [x[0] for x in outputs_l]
train_loss = [x[3] for x in outputs_l]
val_loss = [x[4] for x in outputs_l]

plt.plot(epochs, train_loss, label="training loss")
plt.plot(epochs, val_loss, label="validation loss")
plt.xlabel("epochs")
plt.ylabel("MSE loss")
plt.legend()
plt.savefig('figures/AE_cnn_loss.pdf', format='pdf', bbox_inches='tight')
#plt.show()

# %%
fig, axs = plt.subplots(6, 10, 
                        figsize=(10, 7), 
                        layout="constrained",
                        gridspec_kw={'wspace': 0.1, 'hspace': 0.1})

for i, k in enumerate([0, num_epochs//2, num_epochs-1]):

    inputs = outputs_l[k][1].detach().numpy()
    outputs = outputs_l[k][2].detach().numpy()

    axs[2*i, 0].set_title(f"Epoch {k+1}")
    axs[2*i, 0].set_ylabel("Inputs")

    for j, item in enumerate(inputs):

        if j >= 10: break
        axs[2*i, j].imshow(item[0])
        axs[2*i, j].set_xticks([])
        axs[2*i, j].set_yticks([])

    axs[2*i + 1, 0].set_ylabel("Outputs")
    for j, item in enumerate(outputs):

        if j >= 10: break
        axs[2*i + 1, j].imshow(item[0])
        axs[2*i + 1, j].set_xticks([])
        axs[2*i + 1, j].set_yticks([])

fig.savefig('figures/AE_cnn.pdf', format='pdf', bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## Visualizing the latent space

# %% [markdown]
# We get about 100 samples of each input digit (0, 1, 2, ..., 9) (around 1000 / 64 = 16 batches), compute their encodings in the **latent space**, and try to visualize their distirbution the latent space.

# %%
# torch.save(model_1.state_dict(), "data/AE_linear.pt")

# %%
model_1 = Autoencoder_Linear()
model_1.load_state_dict(torch.load("data/AE_linear.pt"))
model_1.eval()
# Out:
# Autoencoder_Linear(
#   (encoder): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=12, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=12, out_features=2, bias=True)
#   )
#   (decoder): Sequential(
#     (0): Linear(in_features=2, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=64, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=64, out_features=128, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=128, out_features=784, bias=True)
#     (7): Sigmoid()
#   )
# )

# %%
encoder = model_1.encoder.eval()
encoder
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=128, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=128, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=12, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=12, out_features=2, bias=True)
# )

# %%
nb_batches = 16
data_d = {"images" : [], "labels" : []}

for i, batch in enumerate(train_loader):
    
    with torch.no_grad():
        
        images, labels = batch[0], batch[1]
        images = images.reshape(-1, 28*28)

        encoded_images = encoder(images)

        if i == nb_batches:
            break
        else:
            data_d["images"].extend(encoded_images)
            data_d["labels"].extend(labels)

# %%
nb_images = len(data_d["images"])
nb_labels = len(data_d["labels"])

print(f"Nb of encoded images: {nb_images}")
print(f"Nb of labels: {nb_labels}")
# Out:
# Nb of encoded images: 1024
# Nb of labels: 1024

# %%
latent_images = torch.cat(data_d["images"], axis=0).reshape(-1, 2)
labels = torch.tensor(data_d["labels"])

latent_images.shape, labels.shape
# Out:
# (torch.Size([1024, 2]), torch.Size([1024]))

# %%
for i in range(10):
    print((labels==i).sum())
# Out:
# tensor(92)
# tensor(106)
# tensor(115)
# tensor(91)
# tensor(100)
# tensor(100)
# tensor(109)
# tensor(81)
# tensor(117)
# tensor(113)

# %%
import numpy as np

x = latent_images[:, 0]
y = latent_images[:, 1]

plt.figure(figsize=(10, 7))
plt.title("Latent space", size=14)

cm = plt.cm.get_cmap('rainbow', 10)

plt.scatter(x, y, c=labels, alpha=0.6, cmap=cm)

cbar = plt.colorbar()
cbar.set_ticks(np.linspace(0.4, 8.6, 10))
cbar.set_ticklabels(list(range(0, 10)))

plt.savefig('figures/AE_latent_space.pdf', format='pdf', bbox_inches='tight')
# plt.show()

# %% [markdown]
# ## Generative capabilities of the decoder

# %% [markdown]
# ### Idea 1
# - **Uniform sampling** from the latent space
# - Use latent points to estimate the min and max bounds of the uniform distribution.

# %%
import numpy as np

# %%
decoder = model_1.decoder.eval()
decoder
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=64, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=64, out_features=128, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=128, out_features=784, bias=True)
#   (7): Sigmoid()
# )

# %%
minx, maxx = min(x).item(), max(x).item()
miny, maxy = min(y).item(), max(y).item()

minx, maxx, miny, maxy
# Out:
# (-15.887487411499023,
#  33.716094970703125,
#  -19.518972396850586,
#  30.696983337402344)

# %%
# Sample from a uniform distribution on the latent space
xy_min = [minx, miny]
xy_max = [maxx, maxy]

samples_uniform = np.random.uniform(low=xy_min, high=xy_max, size=(100,2))
samples_uniform = torch.tensor(samples_uniform).float()

# %%
samples_uniform.shape
# Out:
# torch.Size([100, 2])

# %%
x = samples_uniform[:, 0]
y = samples_uniform[:, 1]

plt.figure(figsize=(10, 7))
plt.title("Uniform sampling from the latent space", size=14)

cm = plt.cm.get_cmap('rainbow', 10)

plt.scatter(x, y, alpha=0.6)

plt.savefig('figures/AE_uniform_sampling.pdf', format='pdf', bbox_inches='tight')
# plt.show()

# %%
with torch.no_grad():
    decoded_samples = decoder(samples_uniform)

decoded_samples = decoded_samples.reshape(100, 28, 28)
decoded_samples.shape
# Out:
# torch.Size([100, 28, 28])

# %%
fig, axs = plt.subplots(10, 10, 
                        figsize=(10, 10), 
                        layout="constrained",
                        gridspec_kw={'wspace': 0.1, 'hspace': 0.1})

for i in range(10):
    
    samples = decoded_samples[10*i:10*i+10, :, :]
    
    for j in range(10):
    
        axs[i, j].imshow(samples[j, :, :])
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])


fig.savefig('figures/AE_generator_uniform.pdf', format='pdf', bbox_inches='tight')
# plt.show()

# %% [markdown]
# ### Idea 2
# - **Normal sampling** from the latent space
# - Use latent points to estimate the mean and var of the Normal distribution.

# %%
# Sample from a normal distribution on the latent space
mean = torch.mean(latent_images, axis=0)
std = torch.std(latent_images, axis=0)
cov = torch.diag(std)**2

samples_normal = np.random.multivariate_normal(mean, cov, (100))
samples_normal = torch.tensor(samples_normal).float()
samples_normal.shape
# Out:
# torch.Size([100, 2])

# %%
x = samples_normal[:, 0]
y = samples_normal[:, 1]

plt.figure(figsize=(10, 7))
plt.title("Normal sampling from the latent space", size=14)

cm = plt.cm.get_cmap('rainbow', 10)

plt.scatter(x, y, alpha=0.6)

plt.xlim(minx, maxx)
plt.ylim(miny, maxy)

plt.savefig('figures/AE_normal_sampling.pdf', format='pdf', bbox_inches='tight')
# plt.show()

# %%
with torch.no_grad():
    decoded_samples = decoder(samples_normal)

decoded_samples = decoded_samples.reshape(100, 28, 28)
decoded_samples.shape
# Out:
# torch.Size([100, 28, 28])

# %%
fig, axs = plt.subplots(10, 10, 
                        figsize=(10, 10), 
                        layout="constrained",
                        gridspec_kw={'wspace': 0.1, 'hspace': 0.1})

for i in range(10):
    
    samples = decoded_samples[10*i:10*i+10, :, :]
    
    for j in range(10):
    
        axs[i, j].imshow(samples[j, :, :])
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])


fig.savefig('figures/AE_generator_normal.pdf', format='pdf', bbox_inches='tight')
# plt.show()

# %% [markdown]
# **Conclusion:** In both cases, the generated data are somewhat blurry and some numbers are over-represented.
